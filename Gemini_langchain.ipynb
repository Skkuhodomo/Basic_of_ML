# %% [markdown]
# <a href="https://colab.research.google.com/github/Skkuhodomo/Basic_of_ML/blob/main/Gemini_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install h5py
# !pip install typing-extensions
# !pip install wheel
# !pip install chromadb
import chromadb

# %%
from google.colab import drive


drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from IPython.display import Markdown

import os
os.environ["GOOGLE_API_KEY"] = ""

# %%
# %pip install -U --quiet langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 5.3 MB/s eta 0:00:00

# %%
# !pip install -U lida kaleido python-multipart llmx cohere openai typing-extensions
# %pip install -U --quiet langchain tiktoken pypdf sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.7/51.7 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.7/223.7 kB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 79.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: llmx
#     Found existing installation: llmx 0.0.15a0
#     Uninstalling llmx-0.0.15a0:
#       Successfully uninstalled llmx-0.0.15a0
# ...

# %%
# from langchain.chains import RetrievalQA
# from langchain.chat_models import ChatOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("/content/drive/MyDrive/전공안내서(자과캠).pdf")
pages = loader.load_and_split()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
texts = text_splitter.split_documents(pages)

from langchain.embeddings import HuggingFaceEmbeddings

model_name = "jhgan/ko-sbert-nli"
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': True}
hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

docsearch = Chroma.from_documents(texts, hf)
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.46k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/620 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# (…)imilarity_evaluation_sts-dev_results.csv:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# (…)milarity_evaluation_sts-test_results.csv:   0%|          | 0.00/299 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/538 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
 retriever = docsearch.as_retriever(
                                    search_type="mmr",
                                    search_kwargs={'k':3, 'fetch_k': 10})
 retriever.get_relevant_documents("시스템 경영 공학과에 대해 설명")
# Out:
# [Document(page_content='•   시스템경영공학은 시스템을 진단, 분석, 설계, 모형화, 계획, 관리, 통제, 평가하는 모든 과 \n정을 연구하여 최적화, 합리화, 효율화 등을 도모 \n   ⇨ 전공 분야 : 시스템 분석 및 IT, 품질 및 생산성, 제조 및 인간공학, 기술경영 시스템경영공학\n (Systems Management Engineering)\n산업기술\n-설계/생산/제조/물류관리/경영기술\nMan\nMoneyMaterial컴퓨터 및\n정보기술\nInformationEnviroment\n엔지니어링', metadata={'page': 1, 'source': '/content/drive/MyDrive/전공안내서(자과캠).pdf'}),
#  Document(page_content='316＞＞ SUNGKYUNKWAN UNIVERSITY•   시스템을 경영하는 비전과 리더십을 가지게 됩니다. \n•   수학과 통계도 많이 공부합니다. \n■   산업공학으로 출발 : F. W. Taylor가 주창한“과학적 관리(Scientific Management)” 운 동을 \n학문의 뿌리로 삼음 \n■   시스템경영공학 : 일반 공학과는 달리 학문의 대상을 Systems에 맞춤 \n•   시스템은 목적을 가지고 구성 성분들이 자연적/인위적으로 모여서 이루어진 조직 또는 체계를 \n말함 \n   - 예 : 종업원, 재료/부품, 기계로 구성되는 생산/제조 시스템 \n   - 예 : 금융기관과 같이 고객을 위한 서비스로 대표되는 금융 시스템    - 예 : 고객을 만족시키는 제품과 기술을 개발하는 연구개발(R&D) 시스템    - 예 : 다양한 SW와 HW를 통해 정보의 저장, 검색, 처리를 수행하는 정보시스템', metadata={'page': 1, 'source': '/content/drive/MyDrive/전공안내서(자과캠).pdf'}),
# ...

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnableMap

template = """Answer the question as based only on the following context:
{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
gemini = ChatGoogleGenerativeAI(model="gemini-pro", temperature = 0)

chain = RunnableMap({
    "context": lambda x: retriever.get_relevant_documents(x['question']),
    "question": lambda x: x['question']
}) | prompt | gemini

# %%
Markdown(chain.invoke({'question': "시스템 경영공학과에 대해 설명해줭"}).content)
# Out:
# 시스템 경영공학과는 인간, 기계, 물자, 컴퓨터로 구성되는 시스템, 고객을 위한 서비스로 대표되는 시스템, 조직원과 정책경영으로 대표되는 시스템, 벤처 또는 연구개발 시스템 등 사회 전반에 존재하는 다양한 형태의 시스템을 보다 생산적이고 효과적이기 위하여 분석, 설계, 모델링, 계획, 관리, 통제, 평가라는 제반 영역을 필요로 하는 학문입니다.
#
# 시스템 경영공학과는 “시스템”이라는 주제에 대해 효율적 혹은 최적으로 관리 및 경영, 운영하는 방법을 넓게 익힐 수 있는 학문이며, 전통적인 공학을 전공한 사람에게는 부족한, 경영자가 필요로 하는 시스템에 대한 전문적인 지식과 기술을 습득할 수 있는 학문입니다.
